# %% [markdown]
# Major Frameworks used:
#
# - LLMs : LangChain majorly other platforms also exist
# - Fine Tuning :  HuggingFace/ Unsloth
# - RAG/MMRAG : LangChain ecosystem (Langsmith/LangFuse)
# - Agents : LangGraph

# %% [markdown]
# LLM Sources:
#
# - OpenAI
# - Anthrpic
# - Google
# - Meta
# - Microsoft
# - Gork
# - Mistral
# - Opensource LLMs (Huggingface Hub)
#
# All these above have their own SDKs (Software development kits) and Langchain is integrating all these into its own SDK and acting as a unified framework for all the APIs SDK
#
# Platforms (They haven't made their own LLMs but they have integrated multiple LLMs MADE BY OTHERS)
# - Groq
# - Openrouter
# - Perplexity
